# %% [markdown]
# # 0.0. Imports

# %% [markdown]
# ## 0.1. Libraries

# %%
# jupyter core
from IPython.core.display      import display, HTML
from IPython.display           import Image

# requests
from urllib.request import Request, urlopen, urlretrieve
from urllib.error import URLError, HTTPError

# scraping
from bs4 import BeautifulSoup

# data manipulation
import numpy as np
import pandas as pd
import re

# EDA
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 0.2. Helper Functions

# %%
def jupyter_settings():
    # !matplotlib inline
    # !pylab inline
    
    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25, 12]

    plt.rcParams['font.size'] = 18
    
    display(HTML("<style>.container { width:100% !important; }</style>"))
    pd.set_option('display.max_rows', 500)
    pd.set_option('display.max_columns', 500)
    pd.set_option('display.expand_frame_repr', False)
    
    sns.set()

# %%
jupyter_settings()
# Out:
# 'matplotlib' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.
# 'pylab' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.3. Data Scraper

# %% [markdown]
# ### Request test

# %%
# request test
url = 'https://rn.olx.com.br/rio-grande-do-norte/natal/imoveis/aluguel/apartamentos?o=1'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
try:
    req = Request(url, headers=headers)
    response = urlopen(req)
    html = response.read().decode('utf-8')
    print('OK')
except HTTPError as e:
    print(e.status, e.reason)
    
except URLError as e:
    print(e.reason)
# Out:
# OK

# %% [markdown]
# ### Scraper

# %%
# scraping
pages = 29

# list, receiver of info from each renting ad, as a dictionaire
cards = []

for i in range(pages):
    # requesting html
    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
    req = Request('https://rn.olx.com.br/rio-grande-do-norte/natal/imoveis/aluguel/apartamentos?o=' + str(i + 1), headers=headers)
    response = urlopen(req)
    html = response.read().decode('utf-8')
    
    # scraper
    soup = BeautifulSoup(html, 'html.parser')
    anuncios = soup.find('div', {"id": "column-main-content"}).findAll('div', class_="fnmrjs-2 jiSLYe")
    
    for anuncio in anuncios:
        card = {}
        
        # name
        card['NOME'] = anuncio.find("h2").getText()
        
        # value
        span_valor = anuncio.find("span", class_="sc-ifAKCX eoKYee")
        card["VALOR"] = span_valor.get_text() if span_valor else ''
        
        # details
        span_detalhe = anuncio.find("span", class_="sc-1j5op1p-0 lnqdIU sc-ifAKCX eLPYJb")
        card['DETALHES'] = span_detalhe.get_text().split('|') if span_detalhe else ''
        
        # address
        span_endereco = anuncio.find('span', class_="sc-7l84qu-1 ciykCV sc-ifAKCX dpURtf")
        card['ENDEREÇO'] = span_endereco.getText().split(', ')[1] if span_endereco else ''
        
        # appending list values to dict
        cards.append(card)    
    
# saving csv (or json, )
df_raw = pd.DataFrame(cards)
df_raw.head()
# Out:
#                                                 NOME     VALOR  \
# 0                   LC - Apartamento em Ponta Negra!  R$ 1.500
# 1  Alugo apartamento no Alecrim, sua casa no cent...    R$ 650
# 2             LCAP2201 - Ótimo apartamento em Tirol!  R$ 3.600
# 3              Kitnet UFRN cidade jardim capim macio    R$ 800
# 4          Kitinet excelente localização Ponta Negra  R$ 2.500
#
#                                  DETALHES        ENDEREÇO
# 0           [2 quartos ,  58m² ,  1 vaga]     Ponta Negra
# 1                     [2 quartos ,  50m²]         Alecrim
# 2         [2 quartos ,  200m² ,  2 vagas]  Barro Vermelho
# 3                                             Capim Macio
# 4  [1 quarto ,  14m² ,  Condomínio: R$ 0]     Ponta Negra

# %%
df_raw.to_csv('df_raw.csv')

# %% [markdown]
# # 1.0. Data Cleaning

# %%
df1 = df_raw.copy()

# %%
df1.shape
# Out:
# (1448, 4)

# %%
df1.dtypes
# Out:
# NOME        object
# VALOR       object
# DETALHES    object
# ENDEREÇO    object
# dtype: object

# %% [markdown]
# ### Regex em DETALHES

# %%
# lambda functions and mapping the column DETALHES to separate each section
f_quarto = lambda x: re.findall('[0-9]+ quartos?', str(x))
f_area = lambda x: re.findall('[0-9]+m²', str(x))
f_condominio = lambda x: re.findall('Condomínio: R\$\ [0-9]+', str(x))
f_vaga = lambda x: re.findall('[0-9]+ vagas?', str(x))

df1['QUARTOS'] = list(map(f_quarto, df1['DETALHES']))
df1['AREA'] = list(map(f_area, df1['DETALHES']))
df1['CONDOMINIO'] = list(map(f_condominio, df1['DETALHES']))
df1['VAGAS'] = list(map(f_vaga, df1['DETALHES']))

df1.head()
# Out:
#                                                 NOME     VALOR                                DETALHES        ENDEREÇO      QUARTOS     AREA          CONDOMINIO      VAGAS
# 0                   LC - Apartamento em Ponta Negra!  R$ 1.500           [2 quartos ,  58m² ,  1 vaga]     Ponta Negra  [2 quartos]   ²]                  []   [1 vaga]
# 1  Alugo apartamento no Alecrim, sua casa no cent...    R$ 650                     [2 quartos ,  50m²]         Alecrim  [2 quartos]   ²]                  []         []
# 2             LCAP2201 - Ótimo apartamento em Tirol!  R$ 3.600         [2 quartos ,  200m² ,  2 vagas]  Barro Vermelho  [2 quartos]  ²]                  []  [2 vagas]
# 3              Kitnet UFRN cidade jardim capim macio    R$ 800                                             Capim Macio           []       []                  []         []
# 4          Kitinet excelente localização Ponta Negra  R$ 2.500  [1 quarto ,  14m² ,  Condomínio: R$ 0]     Ponta Negra   [1 quarto]   ²]  [Condomínio: R$ 0]         []

# %%
# lambda function and mapping to extract the number to count each feature
f1_quarto = lambda x: re.findall('[0-9]+', str(x))
f1_area = lambda x: re.findall('[0-9]+', str(x))
f1_condominio = lambda x: re.findall('[0-9]+', str(x))
f1_vaga = lambda x: re.findall('[0-9]+', str(x))
f1_valor = lambda x: re.findall('[0-9]+', str(x))

df1['QUARTOS'] =  list(map(f1_quarto, df1['QUARTOS']))
df1['AREA'] = list(map(f1_area, df1['AREA']))
df1['CONDOMINIO'] = list(map(f1_condominio, df1['CONDOMINIO']))
df1['VAGAS'] = list(map(f1_vaga, df1['VAGAS']))
df1['VALOR'] = list(map(f1_valor, df1['VALOR']))

df1.head()
# Out:
#                                                 NOME     VALOR                                DETALHES        ENDEREÇO QUARTOS   AREA CONDOMINIO VAGAS
# 0                   LC - Apartamento em Ponta Negra!  [1, 500]           [2 quartos ,  58m² ,  1 vaga]     Ponta Negra     [2]   [58]         []   [1]
# 1  Alugo apartamento no Alecrim, sua casa no cent...     [650]                     [2 quartos ,  50m²]         Alecrim     [2]   [50]         []    []
# 2             LCAP2201 - Ótimo apartamento em Tirol!  [3, 600]         [2 quartos ,  200m² ,  2 vagas]  Barro Vermelho     [2]  [200]         []   [2]
# 3              Kitnet UFRN cidade jardim capim macio     [800]                                             Capim Macio      []     []         []    []
# 4          Kitinet excelente localização Ponta Negra  [2, 500]  [1 quarto ,  14m² ,  Condomínio: R$ 0]     Ponta Negra     [1]   [14]        [0]    []

# %% [markdown]
# ### Cleaning Helper Functions

# %%
def list_quartos(n):
    # lista com numeros de quartos
    lst = []
    
    # iterando as strings com valores de numeros de quarto
    for i in n:
        if len(i)>3:
            lst.append(i[-3])
        else:
            lst.append('1') #valores vazios são interpretados como kitnets e insere-se 1 quarto
    
    # convertendo o valor numerico de str para numero
    lst = pd.Series(pd.to_numeric(lst))
    
    return lst

def list_vagas(n):
    # lista com numeros de vagas
    lst = []
    
    # iterando as strings com valores de numeros de quarto
    for i in n:
        if len(i)>3:
            lst.append(i[-3])
        else:
            lst.append('0') #valores vazios são interpretados como 0 vaga
    
    # convertendo o valor em str para numerico int
    lst = pd.Series(pd.to_numeric(lst))
    
    return lst

def list_cond(n):
    # lista com valores de condominio
    lst = []
    
    # iterando as strings com valores de condominio
    for i in n:
        if len(i)>2:
            lst.append(''.join(re.findall('[0-9]+', i)))
        else:
            lst.append(0)
    
    # convertendo os valores em str para numerico int
    lst = pd.Series(pd.to_numeric(lst))
    
    return lst

def list_area(n):
    # lista com valores de area
    lst = []
    
    # iterando as strings com valores de area
    for i in n:
        if len(i)>2:
            lst.append(''.join(re.findall('[0-9]+', i)))
        else:
            lst.append(0)
    
    # convertendo os valores em str para numerico int
    lst = pd.Series(pd.to_numeric(lst))
    
    return lst

# %% [markdown]
# ### Quartos

# %%
list_quartos(df1['QUARTOS'].astype(str))
# Out:
# 0       2
# 1       2
# 2       2
# 3       1
# 4       1
#        ..
# 1443    3
# 1444    2
# 1445    1
# 1446    4
# 1447    2
# Length: 1448, dtype: int64

# %% [markdown]
# ### Vagas

# %%
list_vagas(df1['VAGAS'].astype(str))
# Out:
# 0       1
# 1       0
# 2       2
# 3       0
# 4       0
#        ..
# 1443    2
# 1444    1
# 1445    0
# 1446    3
# 1447    0
# Length: 1448, dtype: int64

# %% [markdown]
# ### Condominio

# %%
list_cond(df1['CONDOMINIO'].astype(str))
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1443    0
# 1444    0
# 1445    0
# 1446    0
# 1447    0
# Length: 1448, dtype: int64

# %% [markdown]
# ### Área

# %%
list_area(df1['AREA'].astype(str))
# Out:
# 0        58
# 1        50
# 2       200
# 3         0
# 4        14
#        ...
# 1443      0
# 1444     46
# 1445     18
# 1446    176
# 1447     57
# Length: 1448, dtype: int64

# %% [markdown]
# ### Valor

# %%
pd.to_numeric(''.join(df1['VALOR'][0]))
# Out:
# numpy.int64

# %%
df1['VALOR'].apply(lambda x: pd.to_numeric(''.join(x), ))
# Out:
# 0       1500.0
# 1        650.0
# 2       3600.0
# 3        800.0
# 4       2500.0
#          ...
# 1443    2700.0
# 1444    1300.0
# 1445     600.0
# 1446    3991.0
# 1447    1536.0
# Name: VALOR, Length: 1448, dtype: float64

# %%
df2 = pd.DataFrame()

df2['NOME'] = df1['NOME']
df2['ENDERECO'] = df1['ENDEREÇO']
df2['QUARTOS'] = list_quartos(df1['QUARTOS'].astype(str))
df2['VAGAS'] = list_vagas(df1['VAGAS'].astype(str))
df2['CONDOMINIO'] = list_cond(df1['CONDOMINIO'].astype(str))
df2['AREA'] = list_area(df1['AREA'].astype(str))
df2['VALOR'] = df1['VALOR'].apply(lambda x: pd.to_numeric(''.join(x), ))

df2.head()
# Out:
#                                                 NOME        ENDERECO  QUARTOS  VAGAS  CONDOMINIO  AREA   VALOR
# 0                   LC - Apartamento em Ponta Negra!     Ponta Negra        2      1           0    58  1500.0
# 1  Alugo apartamento no Alecrim, sua casa no cent...         Alecrim        2      0           0    50   650.0
# 2             LCAP2201 - Ótimo apartamento em Tirol!  Barro Vermelho        2      2           0   200  3600.0
# 3              Kitnet UFRN cidade jardim capim macio     Capim Macio        1      0           0     0   800.0
# 4          Kitinet excelente localização Ponta Negra     Ponta Negra        1      0           0    14  2500.0

# %%
df2.to_csv('df_clean.csv', index=None)

# %% [markdown]
# # 2.0. Data Description

# %% [markdown]
# ### Description Helper Functions

# %%
def num_analysis(num_attributes):
    # Cemtral tendency - mean, median
    ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
    ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

    # Dispersion - std, min, max, range, skew, kurtosis
    d1 = pd.DataFrame(num_attributes.apply(np.std)).T
    d2 = pd.DataFrame(num_attributes.apply(min)).T
    d3 = pd.DataFrame(num_attributes.apply(max)).T
    d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
    d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
    d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

    # concatenate
    m = pd.concat([d2,d3,d4,ct1,ct2,d1,d5,d6]).T.reset_index()
    m.columns = ['attributes','min','max','range','mean','median','std','skew','kurtosis',]
    
    # histogram
    num_hist = num_attributes.hist(bins=30)
    
    # DataFrame
    return m
    
    # Histogram
    return num_hist

# %% [markdown]
# ### Description

# %%
# df2 = pd.read_csv('df_clean.csv')

# %%
df3 = df2.copy()

# %%
df3.dtypes
# Out:
# NOME           object
# ENDERECO       object
# QUARTOS         int64
# VAGAS           int64
# CONDOMINIO      int64
# AREA            int64
# VALOR         float64
# dtype: object

# %%
df3.head()

# filter for area less than 200 m²
# data description for condominio above R$ 50
# Out:
#                                                 NOME        ENDERECO  QUARTOS  VAGAS  CONDOMINIO  AREA   VALOR
# 0                   LC - Apartamento em Ponta Negra!     Ponta Negra        2      1           0    58  1500.0
# 1  Alugo apartamento no Alecrim, sua casa no cent...         Alecrim        2      0           0    50   650.0
# 2             LCAP2201 - Ótimo apartamento em Tirol!  Barro Vermelho        2      2           0   200  3600.0
# 3              Kitnet UFRN cidade jardim capim macio     Capim Macio        1      0           0     0   800.0
# 4          Kitinet excelente localização Ponta Negra     Ponta Negra        1      0           0    14  2500.0

# %%
df3 = df3[(df3['AREA']<=200) & (df3['VALOR']<=5000) & (df3['VALOR']>150)]
df3.shape
# Out:
# (1303, 7)

# %%
num_attributes = df3.select_dtypes(include = ['int64', 'float64'])
cat_attributes = df3.select_dtypes(include = ['object'])

# %%
num_analysis(num_attributes)
# Out:
#    attributes  min     max   range         mean  median         std      skew  kurtosis
# 0     QUARTOS  1.0     4.0     3.0     2.032799     2.0    0.788741  0.278111 -0.592647
# 1       VAGAS  0.0     4.0     4.0     1.036613     1.0    0.744285  0.618924  0.738882
# 2  CONDOMINIO  0.0   950.0   950.0    77.218917     0.0  184.076565  2.417540  5.018603
# 3        AREA  0.0   200.0   200.0    56.841342    56.0   39.418301  0.812087  1.426135
# 4       VALOR  0.0  5000.0  5000.0  1532.611747  1400.0  901.668205  1.011679  1.018172

# %%
sns.pairplot(num_attributes)

# %%
cat_attributes.apply(lambda x: x.unique().shape)
# Out:
#    NOME  ENDERECO
# 0  1262        31

# %%
cat_attributes['ENDERECO'].unique()
# Out:
# array(['Ponta Negra', 'Alecrim', 'Barro Vermelho', 'Capim Macio',
#        'Nossa Senhora de Nazaré', 'Nossa Senhora da Apresentação',
#        'Lagoa Nova', 'Neópolis', 'Pitimbu', 'Candelária', 'Tirol',
#        'Dix-Sept Rosado', 'Rocas', 'Nova Descoberta', 'Petrópolis',
#        'Felipe Camarão', 'Quintas', 'Areia Preta', 'Planalto', 'Pajuçara',
#        'Cidade Alta', 'Cidade da Esperança', 'Bom Pastor', 'Ribeira',
#        'Potengi', 'Praia do Meio', 'Lagoa Azul', 'Cidade Nova',
#        'Lagoa Seca', 'Redinha', 'Igapó'], dtype=object)

# %% [markdown]
# # EDA

# %%
df4 = df3[(df3['ENDERECO'].str.contains('Capim Macio|Ponta Negra|Petrópolis|Tirol')) & df3['NOME'].str.contains('Quarto|Kitnet|Flat')]

df4.shape
# Out:
# (87, 7)

# %%
df4.head(40)
# Out:
#                                                   NOME     ENDERECO  QUARTOS  VAGAS  CONDOMINIO  AREA   VALOR
# 3                Kitnet UFRN cidade jardim capim macio  Capim Macio        1      0           0     0   800.0
# 7    Kitnet em Capim Macio, do lado do Shopp Cidade...  Capim Macio        1      1           0    30   650.0
# 25   Aluga-se Apartamento / Kitnet em Ponta Negra M...  Ponta Negra        1      0           0     0   800.0
# 26   Flat em Ponta negra 150 reais a diária top de ...  Ponta Negra        1      1           0    50   150.0
# 38   Flat para Locação em Natal, Ponta Negra, 1 dor...  Ponta Negra        1      1           0    30   800.0
# 40     Kitnets para alugar em Mirassol, próximo a UFRN  Capim Macio        1      0           0     0   600.0
# 56   Flat Mobiliado no Ocean View em Petrópolis com...   Petrópolis        1      0           0    50  1800.0
# 87                             Flat conjunto Alagamar   Ponta Negra        1      1           0     0  1200.0
# 110  Alugo apartamento com 02 Quartos no Ahead Pont...  Ponta Negra        2      1           0     0  3000.0
# 115  Aluguel - Apartamento em Ponta Negra - Açai Fl...  Ponta Negra        1      0           0    40  1703.0
# 128  Aluguel - Apartamento em Ponta Negra - Uma Suí...  Ponta Negra        1      0           0    36  1701.0
# 131                      Flat em ponta negra beira mar  Ponta Negra        1      1           0     0   180.0
# 157                          Alugo Kitnet Capim Macio   Capim Macio        1      0           0     0   650.0
# 159  Aluguel - Apartamento em Ponta Negra - 1 suíte...  Ponta Negra        1      0           0    40  1500.0
# 171                                      Potengi Flat!   Petrópolis        1      1           0    60  2000.0
# 177                      Flat Mobiliado em Areia Preta   Petrópolis        1      1           0    35  2001.0
# 179  Aluga-se, Apto com 2Quartos sendo 1Suite, em C...  Capim Macio        2      1           0    56  1588.0
# 206  Flat com 2 dormitórios para alugar, 60 m² por ...   Petrópolis        2      0           0    60  2000.0
# 222  Kitnet com 1 dormitório para alugar, 12 m² por...  Capim Macio        1      1           0    12  1000.0
# 237  Aluguel - Apartamento em Ponta Negra - Açai Fl...  Ponta Negra        1      0           0    36  1702.0
# 246                          Flat com garagem no Tirol        Tirol        1      1           0    40   950.0
# 257                              Flat Interatlantico!!   Petrópolis        1      1           0    46  2500.0
# 268  Aluguel - Apartamento em Ponta Negra - Açai Fl...  Ponta Negra        1      0           0    36  1600.0
# 271        Edifício Granada Flat/ Ponta Negra-Natal RN  Ponta Negra        1      1           0    53  1600.0
# 280  Flat com 1 dormitório para alugar, 58 m² por R...   Petrópolis        1      1           0    58  1800.0
# 281  Flat com 1 dormitório para alugar, 35 m² por R...   Petrópolis        1      1           0    35  2000.0
# 294  Flat Macarena com 2\4 em ponta negra com excel...  Ponta Negra        2      0           0    40  1600.0
# 307            Belíssimo Flat no Ocean View - 1 quarto   Petrópolis        1      1           0    50  2000.0
# 332  Flat mobiliado em Petrópolis no Ocean View com...   Petrópolis        1      1           0    40  2000.0
# 338  LCFL0172 - Flat totalmente mobiliado em Ponta ...  Ponta Negra        1      1           0    35  1500.0
# 339              LCFL0101 - excelente Flat Ocean View!   Petrópolis        1      1           0    50  2000.0
# 370  Apartamento no Condomínio Açaí Flat ponta negr...  Ponta Negra        1      0           0    36  1750.0
# 379  Alugo Excelente Flat no Ocean View R$: 2.000,0...   Petrópolis        1      1           0    50  2000.0
# 393                 Uma Lindeza Mobilado Em Tirol Flat   Petrópolis        1      1           0    56  2300.0
# 413     Kitnets /Ap. 1 Quarto - Mobiliados em P. Negra  Ponta Negra        1      1           0    30   700.0
# 430                                        Kitnet UFRN  Capim Macio        1      1           0     0   600.0
# 436                           Aluguel Flat Ponta Negra  Ponta Negra        1      1           0    36  1700.0
# 446  R$ 1.500 Aluguel - Apartamento em Ponta Negra ...  Ponta Negra        1      0           0    40  1500.0
# 447  Flat em ponta negra próximo da av engenheiro r...  Ponta Negra        1      1           0    40  1500.0
# 460               Alugo Flat Mobiliado em Ponta Negra.  Ponta Negra        1      1           0    35  1300.0

# %%
num_attributes = df4.select_dtypes(include = ['int64', 'float64'])
cat_attributes = df4.select_dtypes(include = ['object'])

num_analysis(num_attributes)
# Out:
#    attributes    min     max   range         mean  median         std      skew   kurtosis
# 0     QUARTOS    1.0     3.0     2.0     1.264368     1.0    0.556255  2.041666   3.193660
# 1       VAGAS    0.0     4.0     4.0     0.735632     1.0    0.633541  1.393870   6.721836
# 2  CONDOMINIO    0.0   950.0   950.0    13.689655     0.0  104.154870  8.615242  76.729770
# 3        AREA    0.0   118.0   118.0    39.517241    40.0   22.742872  0.291642   1.560416
# 4       VALOR  150.0  3200.0  3050.0  1484.114943  1588.0  675.689693  0.107788  -0.227795

# %%
sns.pairplot(num_attributes)

# %%
sns.scatterplot(x='VALOR', y='AREA', hue='ENDERECO', data=df4, s=150)
# Out:
# <AxesSubplot:xlabel='VALOR', ylabel='AREA'>

# %%
df3.boxplot(column=['VALOR'], by='ENDERECO', rot=90, fontsize=20)
# Out:
# <AxesSubplot:title={'center':'VALOR'}, xlabel='ENDERECO'>

# %%
# !pip requirements
